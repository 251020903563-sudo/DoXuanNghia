# %%
5.1
areas = ["chuong ga", 11.11, "chuong bo",22.22, "chuong de",22.22, "chuong heo",11.11, "ao ca",11.11]
areas[-1] =11.11
areas[3] = 'chuong bo rat to'
print(areas)
# Out:
# ['chuong ga', 11.11, 'chuong bo', 'chuong bo rat to', 'chuong de', 22.22, 'chuong heo', 11.11, 'ao ca', 11.11]

# %%
5.2
areas = ["phong hoc 1",11.11, "phong thi nghiem",22.22, "phong thuc hanh",22.22,
         "phong hoc 2",11.11, "phong hoc 3",11.11]
areas_1 = areas  + ["phong hop",22.22]
areas_2 = list(areas_1)
areas_2.extend(["phong sd",22.22])
print(areas_1)
print(areas_2)
# Out:
# ['phong hoc 1', 11.11, 'phong thi nghiem', 22.22, 'phong thuc hanh', 22.22, 'phong hoc 2', 11.11, 'phong hoc 3', 11.11, 'phong hop', 22.22]
# ['phong hoc 1', 11.11, 'phong thi nghiem', 22.22, 'phong thuc hanh', 22.22, 'phong hoc 2', 11.11, 'phong hoc 3', 11.11, 'phong hop', 22.22, 'phong sd', 22.22]

# %%
5.3
areas = ["tang 1", 11.11, "phong yoga",22.22,
        "phong  cafe",22.22, "tang 2",11.11,
         "tang 3", 11.11, "ho boi rieng",22.22,
         "nha de xe",22.22]
del(areas[-5])
del(areas[-2])
print(areas)

# %%
5.4
areas = [11.11,18.18,22.22,11.11,11.11]
areas_copy = list(areas)
areas_copy[0] =7.0
print(areas)
# Out:
# [11.11, 18.18, 22.22, 11.11, 11.11]

# %%
6.1
var1 = [2, 4, 6, 8]
var2 = True
print(type(var2))
print(len(var1))
out2 = int(var2)
# Out:
# <class 'bool'>
# 4

# %%
6.2 
help(complex)
# Out:
# Help on class complex in module builtins:
#
# class complex(object)
#  |  complex(real=0, imag=0)
#  |
#  |  Create a complex number from a real part and an optional imaginary part.
#  |
#  |  This is equivalent to (real + imag*1j) where imag defaults to 0.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __complex__(self, /)
#  |      Convert this value to exact type complex.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Convert to a string according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
# ...

# %%
6.3
help(sorted)
first = [11.11,22.22,22.22]
second  = [11.11,11.11]
full = first + second
full_sorted = sorted(full, reverse=True)
print(full_sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.
#
# [22.22, 22.22, 11.11, 10.75, 9.5]

# %%
7.1
room = "phong vui choi"
room_up = room.upper()
print(room, room_up)
print(len(room))
# Out:
# poolhouse POOLHOUSE
# 9

# %%
7.2
areas = [11.11,18.18, 20.20, 11.11, 9.50]
print(areas.index(20))
print(areas.count(14.5))
\

# %%
7.3
areas = [11.11,18.18,20.20,11.11,11.11]
areas.append(25.25)
areas.append(15.15)
print(areas)
areas.reverse()
print(areas)

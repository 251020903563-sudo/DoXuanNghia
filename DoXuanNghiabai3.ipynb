# %%
3.1
roof=20
kitchen=20
livingroom=30
bedroom=20
bathroom=20
garden=1000
areas=[roof,kitchen,livingroom,bedroom,bathroom,garden]
print(areas)
# Out:
# [20, 20, 30, 20, 20, 1000]

# %%
3.2
roof=20
kitchen=20
livingroom=30
bedroom=20
bathroom=20
garden=1000
areas=[roof,"kitchen",livingroom,"bedroom",bathroom,garden]
print(areas)

# %%
3.3
roof=20
kitchen=20
liv=30
bed=20
bathroom=20
house=[["roof top",roof],
       ["living room",liv],
       ["bed room",bed]]
print(house)
print(type(house))
# Out:
# [['roof top', 20], ['living room', 30], ['bed room', 20]]
# <class 'list'>

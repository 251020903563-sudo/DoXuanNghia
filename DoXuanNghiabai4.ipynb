# %%
4.1
areas = ["hallway",15,"kitchen",15,"living room",20,"bedroom",15, "bathroom",15]
print(areas[1])
print(areas[3])
print(areas[5])
# Out:
# 15
# 15
# 20

# %%
4.2
areas = ["hallway",15,"kitchen",15,"living room",20,"bedroom",15, "bathroom",15]
run_fun_area=areas[3]+areas[-3]
print(run_fun_area)
# Out:
# 30

# %%
areas = ["hallway",15,"kitchen",15,"living room",20,"bedroom",15, "bathroom",15]
downstairs=areas[0:5]
upstairs = areas[5:-1]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 15, 'kitchen', 15, 'living room']
# [20, 'bedroom', 15, 'bathroom']

# %%
4.4
areas = ["hallway",15,"kitchen",15,"living room",20,"bedroom",15, "bathroom",15]
downstairs = areas[:3]
upstairs = areas[4:]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 15, 'kitchen']
# ['living room', 20, 'bedroom', 15, 'bathroom', 15]

# %%
x = [["a", "b", "c"],
     ["d", "e", "f"],
     ["g", "h", "i"]]
x[1][0]
x[2][:1]
# Out:
# ['g']

# %%
2.1
x=10
print(X)

# %%
2.2
savings=1000000000000000000000000000000
factor=1111111111111.1111111111111
result=savings*factor**4
print(result)
# Out:
# 1.5241579027587258e+78

# %%
2.3
a=123
print(type(savings))
b=456
print(type(factor))
# Out:
# <class 'int'>
# <class 'float'>

# %%
2.4
years=10101010
month=1.001
desc="Data Science"
days= years * month
print(type(days))
doubledesc= desc*2
print(doubledesc)
# Out:
# <class 'float'>
# Data ScienceData Science

# %%
2.5
moneys=10000000000
bank=10000000000*1.15**20
print(str(moneys)+str(bank))
pi_string="3.1416"
pi_float=float(pi_string)
# Out:
# 10000000000163665373929.46088
